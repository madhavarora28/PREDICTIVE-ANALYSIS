# %%
import pandas as pd
import numpy as np

# %%
miles_df=pd.read_csv("C:\\Users\\HP\\Downloads\\us-airlines-monthly-aircraft-miles-flown.csv",header = 0,parse_dates = [0])

# %%
miles_df
# Out:
#         Month  MilesMM
# 0  1963-01-01     6827
# 1  1963-02-01     6178
# 2  1963-03-01     7084
# 3  1963-04-01     8162
# 4  1963-05-01     8462
# ..        ...      ...
# 91 1970-08-01    14057
# 92 1970-09-01    16234
# 93 1970-10-01    12389
# 94 1970-11-01    11595
# 95 1970-12-01    12772
#
# [96 rows x 2 columns]

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_df['MilesMM'].plot()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.regplot(x=miles_df.index.values, y=miles_df['MilesMM'])
# Out:
# <Axes: ylabel='MilesMM'>

# %% [markdown]
# # Removing Seasonality

# %%
miles_df['year'] = miles_df['Month'].dt.year

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year
# 0 1963-01-01     6827  1963
# 1 1963-02-01     6178  1963
# 2 1963-03-01     7084  1963
# 3 1963-04-01     8162  1963
# 4 1963-05-01     8462  1963

# %%
miles_df.groupby('year')['MilesMM'].mean()
# Out:
# year
# 1963     8300.250000
# 1964     8849.333333
# 1965     9619.250000
# 1966     9929.500000
# 1967    10542.916667
# 1968    10747.916667
# 1969    11972.000000
# 1970    13124.750000
# Name: MilesMM, dtype: float64

# %%
miles_df.groupby('year')['MilesMM'].mean().plot();

# %%
# creating lag plot

miles_df['lag1'] = miles_df['MilesMM'].shift(1)

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year    lag1
# 0 1963-01-01     6827  1963     NaN
# 1 1963-02-01     6178  1963  6827.0
# 2 1963-03-01     7084  1963  6178.0
# 3 1963-04-01     8162  1963  7084.0
# 4 1963-05-01     8462  1963  8162.0

# %%
sns.scatterplot(x = miles_df['lag1'],y = miles_df['MilesMM'])
# Out:
# <Axes: xlabel='lag1', ylabel='MilesMM'>

# %% [markdown]
# # Lag plot

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(miles_df['MilesMM'])

# X MilesMM
# y lag
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# # AutoCorrelation Plots

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(miles_df['MilesMM'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>
